# %%
# Crime type data analysis

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
crime_df = pd.read_csv('merged.csv')


neighborhood_counts = crime_df['Neighborhood'].value_counts().reset_index()
neighborhood_counts.columns = ['Neighborhood', 'Crime Count']

top_5_counts = neighborhood_counts.head(5)

bottom_5_counts = neighborhood_counts.tail(5).sort_values(by='Crime Count', ascending=False)

print("Top 5 neighborhoods with the most crimes:")
print(top_5_counts)

print("\nBottom 5 neighborhoods with the least crimes:")
print(bottom_5_counts)
# Out:
# Top 5 neighborhoods with the most crimes:
#       Neighborhood  Crime Count
# 0    Cambridgeport        14496
# 1   East Cambridge        12350
# 2  North Cambridge        10011
# 3    Mid-Cambridge         9932
# 4           Area 4         9535
#
# Bottom 5 neighborhoods with the least crimes:
#         Neighborhood  Crime Count
# 8   Inman/Harrington         5818
# 9          Highlands         2639
# 10           Agassiz         2622
# 11               MIT         2017
# 12   Strawberry Hill         1586

# %%
# Bar graph
plt.title('Frequency of datapoints per Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Count of Datapoints')
sns.barplot(top_5_counts, x='Neighborhood', y = 'Crime Count')
sns.barplot(bottom_5_counts, x='Neighborhood', y = 'Crime Count')

# Displaying legend
orange_patch = plt.Line2D([0], [0], color='blue', linewidth=4, label='Top')
blue_patch = plt.Line2D([0], [0], color='orange', linewidth=4, label='Bottom')
plt.legend(handles=[orange_patch, blue_patch], loc='upper right')

# %%
crime_count = crime_df['Crime'].value_counts().reset_index()
crime_count.columns = ['Crime', 'Crime Count']

top_5_counts = crime_count.head(5)

bottom_5_counts = crime_count.tail(5).sort_values(by='Crime Count', ascending=False)

# %%
# Bar graph
plt.title('Frequency of datapoints per Crime type')
plt.xlabel('Crime type')
plt.ylabel('Count of Datapoints')
sns.barplot(top_5_counts, x='Crime', y = 'Crime Count')
sns.barplot(bottom_5_counts, x='Crime', y = 'Crime Count')

# Displaying legend
plt.xticks(rotation=60)

orange_patch = plt.Line2D([0], [0], color='blue', linewidth=4, label='Top')
blue_patch = plt.Line2D([0], [0], color='orange', linewidth=4, label='Bottom')
plt.legend(handles=[orange_patch, blue_patch], loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=5'>6</a> sns.barplot(bottom_5_counts, x='Crime', y = 'Crime Count')
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=7'>8</a> # Displaying legend
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=8'>9</a> label.set_rotation(60)
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=10'>11</a> orange_patch = plt.Line2D([0], [0], color='blue', linewidth=4, label='Top')
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=11'>12</a> blue_patch = plt.Line2D([0], [0], color='orange', linewidth=4, label='Bottom')
#
# ...
